# %% [markdown]
# <a href="https://www.kaggle.com/code/vuanhduy/cohort-analysis-of-olist-dataset-by-sql?scriptVersionId=131435204" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# Thank you Olist for public E-commerce Dataset for all could practice data analysis. I am a data analysis learner and I try to do cohort analysis by SQL for sellers in 2017. This is my reference for my practice in github: https://github.com/AnhDuyVu/VADuy. I would be very glad to receive any suggestions for improvement.
